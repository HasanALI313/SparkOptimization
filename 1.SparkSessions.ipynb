# %% [markdown]
# # Create a Spark Session
# - In databricks a session is created by Databricks in out spark cluster
# - The session is already created for us.
# - spark = SparkSesstion
# - from pyspark.sql import SparkSession is the same as
# spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()

# %%
spark.conf.set
